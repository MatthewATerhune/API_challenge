# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&"

cloudiness = []
country = []
date = []
max_temp = []
humidity = []
lat = []
lng = []
wind_speed = []
city_name = []

# Loop through cities making the API call
i = 1
for city in cities:
    query_url = url + "appid=" + weather_api_key + "&q=" + city
    response = requests.get(query_url).json()
    # print(response)
    # break
    
    try:
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        max_temp.append(response["main"]['temp_max'])
        humidity.append(response["main"]['humidity'])
        lat.append(response["coord"]["lat"])  
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_name.append(response["name"])
        print(f"Processing record {i}|{city}")
        i+=1
        
    except (KeyError):
        print("City name not available.")
# Out:
# Processing record 1|mahon
# Processing record 2|saint-philippe
# Processing record 3|pueblo nuevo
# Processing record 4|punta arenas
# Processing record 5|albany
# Processing record 6|cherskiy
# Processing record 7|vao
# Processing record 8|bluff
# Processing record 9|ushuaia
# Processing record 10|hobart
# Processing record 11|kattivakkam
# Processing record 12|avarua
# Processing record 13|buala
# Processing record 14|bowen
# Processing record 15|neiafu
# Processing record 16|port hardy
# Processing record 17|jamestown
# Processing record 18|airai
# City name not available.
# Processing record 19|yellowknife
# Processing record 20|kaseda
# Processing record 21|muroto
# Processing record 22|hilo
# Processing record 23|tsogni
# City name not available.
# Processing record 24|georgetown
# Processing record 25|kapaa
# Processing record 26|floro
# Processing record 27|nova olimpia
# Processing record 28|puerto ayora
# Processing record 29|cape town
# Processing record 30|thabazimbi
# Processing record 31|klaksvik
# Processing record 32|atuona
# Processing record 33|busselton
# Processing record 34|altamira
# City name not available.
# Processing record 35|dikson
# Processing record 36|laguna
# Processing record 37|ornskoldsvik
# Processing record 38|rikitea
# Processing record 39|chernyshevskiy
# Processing record 40|xingyi
# Processing record 41|bredasdorp
# Processing record 42|longyearbyen
# Processing record 43|maceio
# Processing record 44|gao
# Processing record 45|barrow
# Processing record 46|topolobampo
# Processing record 47|butaritari
# Processing record 48|saint george
# Processing record 49|port alfred
# Processing record 50|greymouth
# City name not available.
# Processing record 51|sept-iles
# Processing record 52|huarmey
# Processing record 53|victoria
# Processing record 54|tiksi
# City name not available.
# Processing record 55|saskylakh
# Processing record 56|mar del plata
# Processing record 57|lebu
# Processing record 58|hermanus
# Processing record 59|khandyga
# Processing record 60|kabare
# Processing record 61|suclayin
# Processing record 62|marsa matruh
# Processing record 63|ashoknagar
# Processing record 64|nikolskoye
# Processing record 65|cabo san lucas
# Processing record 66|saldanha
# Processing record 67|thompson
# Processing record 68|porto santo
# Processing record 69|eureka
# Processing record 70|tambo
# Processing record 71|upernavik
# Processing record 72|wajid
# Processing record 73|geraldton
# Processing record 74|pekan
# Processing record 75|atagay
# Processing record 76|hofn
# Processing record 77|new norfolk
# City name not available.
# Processing record 78|ahuimanu
# Processing record 79|le port
# Processing record 80|kenora
# Processing record 81|salalah
# City name not available.
# Processing record 82|pisco
# Processing record 83|kahului
# Processing record 84|codrington
# Processing record 85|hithadhoo
# City name not available.
# Processing record 86|chuy
# Processing record 87|turan
# Processing record 88|moranbah
# City name not available.
# Processing record 89|penhold
# Processing record 90|tasiilaq
# Processing record 91|mataura
# City name not available.
# Processing record 92|narsaq
# Processing record 93|clyde river
# Processing record 94|artigas
# Processing record 95|mumbwa
# Processing record 96|galesburg
# Processing record 97|bambous virieux
# Processing record 98|plettenberg bay
# Processing record 99|champerico
# Processing record 100|jalcocotan
# Processing record 101|naze
# Processing record 102|nynashamn
# Processing record 103|mayo
# Processing record 104|yuxia
# Processing record 105|port elizabeth
# Processing record 106|jackson
# Processing record 107|iqaluit
# Processing record 108|guerrero negro
# Processing record 109|bethel
# Processing record 110|acapulco
# Processing record 111|souillac
# Processing record 112|vardo
# Processing record 113|nome
# Processing record 114|ribas do rio pardo
# Processing record 115|luderitz
# Processing record 116|bandarbeyla
# Processing record 117|chokurdakh
# Processing record 118|rivas
# Processing record 119|skowhegan
# Processing record 120|taoudenni
# Processing record 121|ritchie
# Processing record 122|poum
# Processing record 123|tombouctou
# City name not available.
# Processing record 124|thinadhoo
# Processing record 125|san alberto
# Processing record 126|belyy yar
# Processing record 127|panama city
# Processing record 128|constitucion
# Processing record 129|gigmoto
# Processing record 130|san patricio
# Processing record 131|kaitangata
# Processing record 132|anchorage
# Processing record 133|rio claro
# Processing record 134|maltahohe
# Processing record 135|ribeira grande
# Processing record 136|durban
# Processing record 137|olinda
# City name not available.
# Processing record 138|pevek
# Processing record 139|stanislav
# Processing record 140|hami
# Processing record 141|carnarvon
# Processing record 142|trento
# Processing record 143|maralal
# Processing record 144|shingu
# Processing record 145|sobolevo
# Processing record 146|paamiut
# Processing record 147|arraial do cabo
# City name not available.
# Processing record 148|riverton
# Processing record 149|rincon
# Processing record 150|hirtshals
# Processing record 151|santa helena
# Processing record 152|broome
# Processing record 153|kavaratti
# City name not available.
# Processing record 154|owen sound
# Processing record 155|aklavik
# Processing record 156|cairns
# Processing record 157|talnakh
# Processing record 158|warrnambool
# Processing record 159|bay roberts
# Processing record 160|flin flon
# Processing record 161|saint-joseph
# Processing record 162|gananoque
# Processing record 163|chardara
# Processing record 164|tadine
# Processing record 165|balabac
# Processing record 166|sambava
# Processing record 167|pacific grove
# City name not available.
# Processing record 168|aviles
# Processing record 169|fortuna
# Processing record 170|gravdal
# Processing record 171|mogadishu
# Processing record 172|great yarmouth
# City name not available.
# Processing record 173|ponta do sol
# Processing record 174|qaqortoq
# Processing record 175|arrecife
# Processing record 176|bilma
# Processing record 177|kilindoni
# Processing record 178|olafsvik
# Processing record 179|antofagasta
# Processing record 180|itarema
# City name not available.
# Processing record 181|pitimbu
# Processing record 182|krasnoselkup
# Processing record 183|nisia floresta
# Processing record 184|vila
# Processing record 185|lorengau
# Processing record 186|kodiak
# Processing record 187|faya
# Processing record 188|mattoon
# Processing record 189|northam
# Processing record 190|umm lajj
# Processing record 191|pop
# Processing record 192|lamu
# Processing record 193|zhigansk
# Processing record 194|magadan
# Processing record 195|padang
# Processing record 196|richards bay
# Processing record 197|portobelo
# Processing record 198|garden city
# Processing record 199|labuhan
# Processing record 200|port hedland
# City name not available.
# Processing record 201|vaini
# Processing record 202|tete
# Processing record 203|evensk
# Processing record 204|san vicente
# Processing record 205|gladstone
# Processing record 206|kidal
# Processing record 207|havelock
# Processing record 208|north platte
# Processing record 209|esperance
# Processing record 210|rosendal
# Processing record 211|akyab
# Processing record 212|puerto del rosario
# Processing record 213|laiwu
# Processing record 214|kruisfontein
# Processing record 215|tuktoyaktuk
# Processing record 216|ancud
# Processing record 217|southbridge
# Processing record 218|doha
# City name not available.
# Processing record 219|tuatapere
# Processing record 220|kasama
# City name not available.
# Processing record 221|severo-kurilsk
# Processing record 222|imeni poliny osipenko
# Processing record 223|fairview
# Processing record 224|sisimiut
# Processing record 225|kalmunai
# Processing record 226|mabaruma
# Processing record 227|bilibino
# Processing record 228|kant
# Processing record 229|pampa
# City name not available.
# Processing record 230|bonfim
# Processing record 231|bakchar
# Processing record 232|qaanaaq
# Processing record 233|quatre cocos
# Processing record 234|viedma
# Processing record 235|karpathos
# Processing record 236|ketchikan
# Processing record 237|castro
# Processing record 238|vanimo
# Processing record 239|puerto escondido
# Processing record 240|nanortalik
# Processing record 241|ayan
# Processing record 242|ormara
# Processing record 243|matagami
# Processing record 244|sinnamary
# City name not available.
# Processing record 245|pangody
# Processing record 246|norman wells
# Processing record 247|pemba
# Processing record 248|isla mujeres
# Processing record 249|ponta delgada
# Processing record 250|kamenka
# Processing record 251|lagoa
# City name not available.
# Processing record 252|san quintin
# City name not available.
# Processing record 253|biak
# Processing record 254|bontang
# Processing record 255|mattru
# Processing record 256|merauke
# Processing record 257|severnyy
# Processing record 258|kyra
# Processing record 259|mahebourg
# Processing record 260|tsumeb
# Processing record 261|simao
# Processing record 262|faanui
# Processing record 263|husavik
# Processing record 264|kungurtug
# Processing record 265|belmonte
# Processing record 266|safford
# Processing record 267|huaihua
# Processing record 268|anito
# City name not available.
# Processing record 269|tambacounda
# Processing record 270|balagansk
# Processing record 271|xuddur
# Processing record 272|dingle
# Processing record 273|nadadores
# Processing record 274|vestmanna
# Processing record 275|bereda
# Processing record 276|beitbridge
# Processing record 277|te anau
# Processing record 278|ufimskiy
# Processing record 279|bathsheba
# City name not available.
# Processing record 280|the valley
# Processing record 281|tilichiki
# Processing record 282|buchanan
# City name not available.
# Processing record 283|aksarka
# Processing record 284|coahuayana
# Processing record 285|iwaki
# Processing record 286|zorgo
# Processing record 287|pyay
# Processing record 288|hamilton
# Processing record 289|port blair
# City name not available.
# Processing record 290|cayenne
# Processing record 291|trincomalee
# Processing record 292|banda aceh
# Processing record 293|hanstholm
# Processing record 294|meulaboh
# Processing record 295|miandrivazo
# City name not available.
# Processing record 296|mackenzie
# Processing record 297|kaeo
# Processing record 298|troy
# Processing record 299|homer
# Processing record 300|barcelos
# Processing record 301|kiama
# Processing record 302|nishihara
# Processing record 303|estevan
# Processing record 304|honningsvag
# Processing record 305|muramatsu
# Processing record 306|tautira
# Processing record 307|saiki
# Processing record 308|jalu
# Processing record 309|east london
# Processing record 310|santa isabel
# Processing record 311|mosquera
# Processing record 312|bajil
# Processing record 313|gainesville
# Processing record 314|auki
# Processing record 315|baculin
# Processing record 316|rabo de peixe
# Processing record 317|nemuro
# Processing record 318|alice springs
# Processing record 319|carmarthen
# Processing record 320|hirara
# Processing record 321|mahanoro
# Processing record 322|boddam
# Processing record 323|touros
# Processing record 324|mandan
# Processing record 325|high level
# City name not available.
# Processing record 326|sao jose da coroa grande
# Processing record 327|miyako
# Processing record 328|yala
# Processing record 329|vestmannaeyjar
# City name not available.
# Processing record 330|lixourion
# Processing record 331|sosnovka
# Processing record 332|bengkulu
# Processing record 333|kikwit
# Processing record 334|terra roxa
# Processing record 335|aranos
# Processing record 336|isangel
# Processing record 337|sagua de tanamo
# Processing record 338|tahoua
# Processing record 339|khatanga
# Processing record 340|carutapera
# Processing record 341|chipinge
# Processing record 342|cidreira
# Processing record 343|novorudnyy
# Processing record 344|sitka
# Processing record 345|beringovskiy
# Processing record 346|fukue
# Processing record 347|camargo
# Processing record 348|provideniya
# Processing record 349|omsukchan
# Processing record 350|munxar
# Processing record 351|brecht
# Processing record 352|nadym
# Processing record 353|ous
# Processing record 354|polovinnoye
# Processing record 355|linqing
# Processing record 356|adrar
# Processing record 357|dwarka
# Processing record 358|nalut
# Processing record 359|mujiayingzi
# Processing record 360|amritsar
# Processing record 361|sibu
# Processing record 362|flinders
# Processing record 363|abilene
# Processing record 364|trindade
# Processing record 365|lompoc
# Processing record 366|trairi
# Processing record 367|coolidge
# Processing record 368|sabinas
# Processing record 369|metro
# Processing record 370|mersing
# Processing record 371|otradnoye
# Processing record 372|haines junction
# Processing record 373|cap malheureux
# Processing record 374|wellington
# Processing record 375|fort nelson
# Processing record 376|fayetteville
# City name not available.
# Processing record 377|yulara
# Processing record 378|ploemeur
# Processing record 379|hervey bay
# City name not available.
# Processing record 380|prince rupert
# Processing record 381|lethem
# City name not available.
# Processing record 382|am timan
# Processing record 383|vuktyl
# Processing record 384|korla
# Processing record 385|huadian
# Processing record 386|northallerton
# City name not available.
# Processing record 387|morehead
# Processing record 388|terney
# Processing record 389|bukachacha
# Processing record 390|wawa
# Processing record 391|baykit
# Processing record 392|pangnirtung
# Processing record 393|swan river
# Processing record 394|muros
# Processing record 395|piacabucu
# City name not available.
# Processing record 396|lakatoro
# Processing record 397|ostrovnoy
# Processing record 398|qrendi
# Processing record 399|vila franca do campo
# Processing record 400|pomi
# Processing record 401|dzaoudzi
# Processing record 402|nago
# Processing record 403|mehamn
# Processing record 404|ambon
# Processing record 405|katobu
# Processing record 406|vladyslavivka
# Processing record 407|urucara
# Processing record 408|ganzhou
# Processing record 409|karratha
# Processing record 410|binzhou
# Processing record 411|coihaique
# City name not available.
# Processing record 412|amahai
# City name not available.
# Processing record 413|pauini
# City name not available.
# Processing record 414|umea
# Processing record 415|mastic beach
# Processing record 416|riyadh
# Processing record 417|sitio novo do tocantins
# Processing record 418|bud
# Processing record 419|gewane
# Processing record 420|seoul
# Processing record 421|ilebo
# Processing record 422|taipei
# Processing record 423|rognan
# Processing record 424|kochki
# Processing record 425|trofors
# Processing record 426|buraydah
# Processing record 427|nouakchott
# Processing record 428|hobyo
# Processing record 429|clarence town
# Processing record 430|alta floresta
# Processing record 431|guaira
# Processing record 432|la gloria
# Processing record 433|yarmouth
# Processing record 434|nuevo ideal
# Processing record 435|juquia
# City name not available.
# Processing record 436|caravelas
# Processing record 437|suez
# City name not available.
# Processing record 438|prince george
# Processing record 439|manokwari
# Processing record 440|borogontsy
# Processing record 441|wanaka
# Processing record 442|lasa
# Processing record 443|bumba
# Processing record 444|washington
# Processing record 445|kokopo
# Processing record 446|chapleau
# Processing record 447|anadyr
# Processing record 448|strelka
# Processing record 449|leningradskiy
# Processing record 450|mamallapuram
# Processing record 451|kloulklubed
# Processing record 452|praia
# Processing record 453|pallasovka
# Processing record 454|kem
# Processing record 455|bodden town
# Processing record 456|urengoy
# Processing record 457|alamogordo
# Processing record 458|mount isa
# Processing record 459|college
# Processing record 460|umm kaddadah
# Processing record 461|teya
# Processing record 462|salinas
# Processing record 463|nouadhibou
# Processing record 464|selma
# Processing record 465|killybegs
# Processing record 466|marfino
# Processing record 467|camacha
# Processing record 468|gorontalo
# Processing record 469|dunedin
# Processing record 470|sao filipe
# Processing record 471|tongliao
# Processing record 472|oranjemund
# Processing record 473|ilulissat
# Processing record 474|kavieng
# Processing record 475|nsanje
# Processing record 476|isla vista
# Processing record 477|njombe
# Processing record 478|pacifica
# City name not available.
# Processing record 479|ust-omchug
# Processing record 480|havre-saint-pierre
# Processing record 481|ngunguru
# Processing record 482|jiangyan
# Processing record 483|gonen
# Processing record 484|torbay
# Processing record 485|kupang
# Processing record 486|cam ranh
# Processing record 487|porto walter
# Processing record 488|roald
# Processing record 489|braganca
# Processing record 490|abu zabad
# Processing record 491|mandalgovi
# Processing record 492|severomorsk
# Processing record 493|gulu
# City name not available.
# Processing record 494|hualmay
# Processing record 495|ugoofaaru
# Processing record 496|brockville
# Processing record 497|atar
# Processing record 498|moberly
# Processing record 499|wells
# Processing record 500|cananeia
# Processing record 501|vostok
# Processing record 502|jawhar
# Processing record 503|marawi
# Processing record 504|nibbar
# Processing record 505|la ronge
# Processing record 506|tura
# Processing record 507|saint-augustin
# Processing record 508|puka
# Processing record 509|vila velha
# Processing record 510|svetlaya
# Processing record 511|sistranda
# Processing record 512|foundiougne
# Processing record 513|alakurtti
# Processing record 514|fairbanks
# Processing record 515|ada
# Processing record 516|kabanjahe
# Processing record 517|hasaki
# Processing record 518|manado
# Processing record 519|sao joao da barra
# Processing record 520|asuncion
# Processing record 521|broken hill
# City name not available.
# Processing record 522|willowmore
# City name not available.
# Processing record 523|alvik
# Processing record 524|parauna
# Processing record 525|crib point
# Processing record 526|avera
# Processing record 527|sur
# Processing record 528|san miguel
# Processing record 529|sorland
# City name not available.
# Processing record 530|zhezkazgan
# Processing record 531|tambopata
# Processing record 532|moyale
# Processing record 533|nelson bay
# Processing record 534|zunyi
# Processing record 535|manbij
# City name not available.
# City name not available.
# Processing record 536|bayir
# Processing record 537|yar-sale
# Processing record 538|alberton
# Processing record 539|sheffield
# Processing record 540|elizabeth city
# Processing record 541|araria
# Processing record 542|chute-aux-outardes
# Processing record 543|batagay-alyta
# Processing record 544|senno
# Processing record 545|wanning
# Processing record 546|coquimbo
# Processing record 547|chopovychi
# Processing record 548|san rafael
# Processing record 549|wuwei
# Processing record 550|novobiryusinskiy
# Processing record 551|tigil
# Processing record 552|karimganj
# City name not available.
# City name not available.
# Processing record 553|maniitsoq
# Processing record 554|zielona gora
# City name not available.
# Processing record 555|rocha
# Processing record 556|liku
# Processing record 557|nara
# City name not available.
# Processing record 558|palimbang
# Processing record 559|araouane
# Processing record 560|jega
# Processing record 561|pilar
# Processing record 562|cabedelo
# Processing record 563|jhalu
# Processing record 564|aban
# Processing record 565|yoichi
# Processing record 566|boyolangu

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame({"City": city_name, 
                        "Lat": lat,
                        "Lng": lng,
                        "Max Temp": max_temp,
                        "Humidity":humidity,
                        "Cloudiness": cloudiness, 
                        "Wind Speed": wind_speed,
                        "Country": country, 
                        "Date": date, 
                                         })

city_df = city_df.rename_axis('City ID')

city_df.head(2)
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City ID
# 0                 Mahon  39.8885   4.2658      57.2        62          20
# 1        Saint-Philippe -21.3585  55.7679      82.4        69          75
#
#          Wind Speed Country        Date
# City ID
# 0              13.8      ES  1618490455
# 1               2.3      RE  1618490455

# %%
city_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  566.000000  566.000000  566.000000  566.000000  566.000000  566.000000
# mean    20.821007   17.161893   60.511537   68.171378   56.236749    8.446007
# std     33.188772   91.706089   23.830246   24.005397   38.903063    5.755286
# min    -54.800000 -175.200000  -16.240000    3.000000    0.000000    0.450000
# 25%     -6.686075  -59.911700   44.600000   56.000000   20.000000    4.340000
# 50%     25.128300   19.637400   66.000000   75.000000   75.000000    6.910000
# 75%     49.707050  101.181200   79.545000   87.000000   95.750000   11.500000
# max     78.218600  179.316700  107.240000  100.000000  100.000000   47.000000
#
#                Date
# count  5.660000e+02
# mean   1.618491e+09
# std    7.137016e+01
# min    1.618490e+09
# 25%    1.618490e+09
# 50%    1.618491e+09
# 75%    1.618491e+09
# max    1.618491e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humid_city = city_df.loc[city_df["Humidity"] > 100]
humid_city.head()
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
city_df.head(10)
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City ID
# 0                 Mahon  39.8885    4.2658     57.20        62          20
# 1        Saint-Philippe -21.3585   55.7679     82.40        69          75
# 2          Pueblo Nuevo  23.3833 -105.3833     49.87        24           2
# 3          Punta Arenas -53.1500  -70.9167     39.20        93          40
# 4                Albany  42.6001  -73.9662     52.00        69         100
# 5              Cherskiy  68.7500  161.3000     12.29        84         100
# 6                   Vao -22.6667  167.4833     75.63        79         100
# 7                 Bluff -46.6000  168.3333     52.00        81         100
# 8               Ushuaia -54.8000  -68.3000     42.80        65          40
# 9                Hobart -42.8794  147.3294     46.40        57          20
#
#          Wind Speed Country        Date
# City ID
# 0             13.80      ES  1618490455
# 1              2.30      RE  1618490455
# 2              6.11      MX  1618490455
# 3             11.50      CL  1618490456
# 4              5.35      US  1618490182
# 5              6.38      RU  1618490456
# 6             16.91      NC  1618490456
# 7              1.01      NZ  1618490456
# 8             13.80      AR  1618490457
# 9              6.91      AU  1618490457

# %%
#  Get the indices of cities that have humidity over 100%.
index_list = city_df[(city_df["Humidity"] > 100)].index
                                  
for index in index_list:
    print(index)

# %%
city_df["City"].count()
# Out:
# 566

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_df = city_df.drop(index_list, inplace=False)
clean_city_df["City"].count()
# Out:
# 566

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# create and label scatter plot
plt.scatter(clean_city_df["Lat"], clean_city_df["Max Temp"], marker="o",edgecolor='b', s=10)
plt.title("City Latitude vs. Max Temperature (Add date)")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
# save scatter
plt.savefig("Weatherpy_Max_Temp_vs_Latitude.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# create and label scatter plot
plt.scatter(clean_city_df["Lat"], clean_city_df["Humidity"], marker="o",edgecolor='b', s=10)
plt.title("City Latitude vs. Humidity(Add date)")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
# save scatter
plt.savefig("Weatherpy_Max_Temp_vs_Humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# create and label scatter plot
plt.scatter(clean_city_df["Lat"], clean_city_df["Cloudiness"], marker="o",edgecolor='b', s=10)
plt.title("City Latitude vs. Cloudiness (Add date)")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
# save scatter
plt.savefig("Weatherpy_Max_Temp_vs_Cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# create and label scatter plot
plt.scatter(clean_city_df["Lat"], clean_city_df["Wind Speed"], marker="o",edgecolor='b', s=10)
plt.title("City Latitude vs. Windspeed (Add date)")
plt.ylabel("Windspeed")
plt.xlabel("Latitude")
plt.grid(True)
# save scatter
plt.savefig("Weatherpy_Max_Temp_vs_Windspeed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# create Northern,souther hemispher  DF then calculate regression
north_hem_df = clean_city_df.loc[clean_city_df["Lat"] > 0]
# north_hem_df.head()
south_hem_df = clean_city_df.loc[clean_city_df["Lat"] <= 0]
# south_hem_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City ID
# 1        Saint-Philippe -21.3585   55.7679     82.40        69          75
# 3          Punta Arenas -53.1500  -70.9167     39.20        93          40
# 6                   Vao -22.6667  167.4833     75.63        79         100
# 7                 Bluff -46.6000  168.3333     52.00        81         100
# 8               Ushuaia -54.8000  -68.3000     42.80        65          40
#
#          Wind Speed Country        Date
# City ID
# 1              2.30      RE  1618490455
# 3             11.50      CL  1618490456
# 6             16.91      NC  1618490456
# 7              1.01      NZ  1618490456
# 8             13.80      AR  1618490457

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_hem_df['Max Temp'].max()
# Out:
# 107.24

# %%
m_temp = north_hem_df['Max Temp']
Lat=north_hem_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(m_temp, Lat)

 # y=mx+b slope calculation
s_fit = m_temp * slope + intercept

line_eq = "y = " + str(round(slope,2))+ "x + " + str(round(intercept,2))

plt.scatter(m_temp,Lat)
plt.plot(m_temp,s_fit,"r--")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.title("Max Temp v Latitude Lineregress model")
plt.xlim(north_hem_df['Max Temp'].min() - 5 ,north_hem_df['Max Temp'].max()+5)
plt.ylim(north_hem_df['Lat'].min() -5,north_hem_df['Lat'].max() +5)
plt.rcParams.update({'font.size': 10})
plt.annotate(line_eq,(-15,10),fontsize=15,color="red")
print(f'r value is: {rvalue}')
plt.savefig("Weatherpy_North_Max_temp_lregress.png")
plt.show()
# Out:
# r value is: -0.8505443147058951

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
m_temp = south_hem_df['Max Temp']
Lat=south_hem_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(m_temp, Lat)

 # y=mx+b slope calculation
s_fit = m_temp * slope + intercept

line_eq = "y = " + str(round(slope,2))+ "x + " + str(round(intercept,2))

plt.scatter(m_temp,Lat)
plt.plot(m_temp,s_fit,"r--")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.title("Max Temp v Latitude Lineregress model")
plt.xlim(south_hem_df['Max Temp'].min() - 5 ,south_hem_df['Max Temp'].max()+5)
plt.ylim(south_hem_df['Lat'].min()-5,south_hem_df['Lat'].max() +5)
plt.rcParams.update({'font.size': 10})
plt.annotate(line_eq,(40,-5),fontsize=15,color="red")
print(f'r value is: {rvalue}')
plt.savefig("Weatherpy_south_Max_temp_lregress.png")
plt.show()
# Out:
# r value is: 0.6589293398167911

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
hum = north_hem_df['Humidity']
Lat=north_hem_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(hum, Lat)

 # y=mx+b slope calculation
s_fit = hum * slope + intercept

line_eq = "y = " + str(round(slope,2))+ "x + " + str(round(intercept,2))

plt.scatter(hum,Lat)
plt.plot(hum,s_fit,"r--")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Humidity v Latitude Lineregress model")
plt.xlim(north_hem_df['Humidity'].min() - 5 ,north_hem_df['Humidity'].max()+5)
plt.ylim(north_hem_df['Lat'].min() -5,north_hem_df['Lat'].max() +5)
plt.rcParams.update({'font.size': 10})
plt.annotate(line_eq,(0,70),fontsize=15,color="red")
print(f'r value is: {rvalue}')
plt.savefig("Weatherpy_North_Hum_lregress.png")
plt.show()
# Out:
# r value is: 0.25464528994616814

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
s_hum = south_hem_df['Humidity']
Lat=south_hem_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_hum, Lat)

 # y=mx+b slope calculation
s_fit = s_hum * slope + intercept

line_eq = "y = " + str(round(slope,2))+ "x + " + str(round(intercept,2))

plt.scatter(s_hum,Lat)
plt.plot(s_hum,s_fit,"r--")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Humidity v Latitude Lineregress model")
plt.xlim(south_hem_df['Humidity'].min() - 5 ,south_hem_df['Humidity'].max()+5)
plt.ylim(south_hem_df['Lat'].min()-5,south_hem_df['Lat'].max() +5)
plt.rcParams.update({'font.size': 10})
plt.annotate(line_eq,(10,0),fontsize=15,color="red")
print(f'r value is: {rvalue}')
plt.savefig("Weatherpy_wouth_hum_lregress.png")
plt.show()
# Out:
# r value is: 0.0896981285070551

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
cloudiness = north_hem_df['Cloudiness']
Lat=north_hem_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(cloudiness, Lat)

 # y=mx+b slope calculation
s_fit = cloudiness * slope + intercept

line_eq = "y = " + str(round(slope,2))+ "x + " + str(round(intercept,2))

plt.scatter(cloudiness,Lat)
plt.plot(cloudiness,s_fit,"r--")
plt.xlabel("Latitude")
plt.ylabel("cloudiness")
plt.title("cloudiness v Latitude Lineregress model")
plt.xlim(north_hem_df['Cloudiness'].min() - 5 ,north_hem_df['Cloudiness'].max()+5)
plt.ylim(north_hem_df['Lat'].min() -5,north_hem_df['Lat'].max() +5)
plt.rcParams.update({'font.size': 10})
plt.annotate(line_eq,(0,75),fontsize=15,color="red")
print(f'r value is: {rvalue}')
plt.savefig("Weatherpy_North_cloud_lregress.png")
plt.show()
# Out:
# r value is: 0.07238773900203166

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
s_cloud = south_hem_df['Cloudiness']
Lat=south_hem_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_cloud, Lat)

 # y=mx+b slope calculation
s_fit = s_cloud * slope + intercept

line_eq = "y = " + str(round(slope,2))+ "x + " + str(round(intercept,2))

plt.scatter(s_cloud,Lat)
plt.plot(s_cloud,s_fit,"r--")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Cloudiness (%)v Latitude Lineregress model")
plt.xlim(south_hem_df['Cloudiness'].min() - 5 ,south_hem_df['Cloudiness'].max()+5)
plt.ylim(south_hem_df['Lat'].min()-5,south_hem_df['Lat'].max() +5)
plt.rcParams.update({'font.size': 10})
plt.annotate(line_eq,(10,0),fontsize=15,color="red")
print(f'r value is: {rvalue}')
plt.savefig("Weatherpy_South_cloud_lregress.png")
plt.show()
# Out:
# r value is: 0.22811663941978366

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
windspeed = north_hem_df['Wind Speed']
Lat=north_hem_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(windspeed, Lat)

 # y=mx+b slope calculation
s_fit = windspeed * slope + intercept

line_eq = "y = " + str(round(slope,2))+ "x + " + str(round(intercept,2))

plt.scatter(windspeed,Lat)
plt.plot(windspeed,s_fit,"r--")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Wind Speed v Latitude Lineregress model")
plt.xlim(north_hem_df['Wind Speed'].min() - 5 ,north_hem_df['Wind Speed'].max()-15)
plt.ylim(north_hem_df['Lat'].min() -5,north_hem_df['Lat'].max() +5)
plt.rcParams.update({'font.size': 10})
plt.annotate(line_eq,(0,75),fontsize=15,color="red")
print(f'r value is: {rvalue}')
plt.savefig("Weatherpy_North_windspeed_lregress.png")
plt.show()
# Out:
# r value is: 0.11055128742550661

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
s_windspeed = south_hem_df['Wind Speed']
Lat=south_hem_df['Lat']
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_windspeed, Lat)

 # y=mx+b slope calculation
s_fit = s_windspeed * slope + intercept

line_eq = "y = " + str(round(slope,2))+ "x + " + str(round(intercept,2))

plt.scatter(s_windspeed,Lat)
plt.plot(s_windspeed,s_fit,"r--")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Wind Speed v Latitude Lineregress model")
plt.xlim(south_hem_df['Wind Speed'].min() - 5 ,south_hem_df['Wind Speed'].max()+5)
plt.ylim(south_hem_df['Lat'].min()-5,south_hem_df['Lat'].max() +5)
plt.rcParams.update({'font.size': 10})
plt.annotate(line_eq,(10,0),fontsize=15,color="red")
print(f'r value is: {rvalue}')
plt.savefig("Weatherpy_south_windspeed_lregress.png")
plt.show()
# Out:
# r value is: -0.2156482084444709
